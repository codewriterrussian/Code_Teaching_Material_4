# %% [markdown]
# # C / C++ 條件判斷與迴圈 50 題：自動檢查版
#
# 本題本依照原本的 C++ 自動檢查 Notebook 擴充為 **C 與 C++ 雙版本**，範圍集中在 Lessons 06–10：
#
# - Lesson 06：`if` 條件判斷
# - Lesson 07：`if / else / else if / switch`
# - Lesson 08：`while / do...while`
# - Lesson 09：`for / break / continue`；C++ 額外練習 `range-based for`
# - Lesson 10：巢狀迴圈與座標式圖形
#
# ## 作答流程
#
# 1. 先執行下面的「C / C++ 自動檢查工具」cell。
# 2. 每題都有兩個作答 cell：
#    - `%%c_answer Q...`：C（C11）
#    - `%%cpp_answer Q...`：C++（C++17）
# 3. **不需要在作答 cell 手動輸入測試資料。**
# 4. 完成某一語言後，執行緊接在該作答 cell 下方的檢查。
# 5. C 與 C++ 使用同一組測試資料與預期輸出。
# 6. 最後執行「總檢查」，可分別查看 C、C++，以及兩者都通過的題數。
#
# > 可以只練 C、只練 C++，或同一題兩種都寫。題目由基礎到稍具整合性；請盡量使用該 Part 指定的控制結構練習。

# %%
# === C / C++ 自動檢查工具：請先執行這個 cell，不要修改 ===
import base64
import json
import os
import shutil
import subprocess
import tempfile
from IPython.core.magic import register_cell_magic

_TEST_CASES = json.loads(
    base64.b64decode("...").decode("utf-8")
)

_ANSWERS = {"C": {}, "CPP": {}}
_RESULTS = {"C": {}, "CPP": {}}

def _normalise_output(text):
    lines = [line.rstrip() for line in text.replace("\r\n", "\n").split("\n")]
    while lines and lines[-1] == "":
        lines.pop()
    return "\n".join(lines)

def _compiler(language):
    language = language.upper()

    if language == "C":
        candidates = ["gcc", "clang", "cc"]
    elif language == "CPP":
        candidates = ["g++", "clang++", "c++"]
    else:
        return None

    for name in candidates:
        compiler_path = shutil.which(name)
        if compiler_path:
            return compiler_path
    return None

def _compile_and_run(source, input_text, language):
    language = language.upper()
    compiler = _compiler(language)

    if compiler is None:
        if language == "C":
            return False, "", "找不到 C 編譯器（gcc / clang / cc）。"
        return False, "", "找不到 C++ 編譯器（g++ / clang++ / c++）。"

    with tempfile.TemporaryDirectory() as td:
        if language == "C":
            src = os.path.join(td, "answer.c")
            compile_cmd = [compiler, "-std=c11", src, "-o", os.path.join(td, "answer")]
        else:
            src = os.path.join(td, "answer.cpp")
            compile_cmd = [compiler, "-std=c++17", src, "-o", os.path.join(td, "answer")]

        exe = os.path.join(td, "answer")

        with open(src, "w", encoding="utf-8") as f:
            f.write(source)

        compile_result = subprocess.run(
            compile_cmd,
            capture_output=True,
            text=True,
        )

        if compile_result.returncode != 0:
            return False, "", compile_result.stderr

        try:
            run_result = subprocess.run(
                [exe],
                input=input_text,
                capture_output=True,
                text=True,
                timeout=5,
            )
        except subprocess.TimeoutExpired:
            return False, "", "程式執行超過 5 秒，請檢查是否有無限迴圈。"

        if run_result.returncode != 0:
            err = run_result.stderr or f"程式結束碼：{run_result.returncode}"
            return False, run_result.stdout, err

        return True, run_result.stdout, ""

@register_cell_magic
def c_answer(line, cell):
    qid = line.strip().upper()
    _ANSWERS["C"][qid] = cell
    print(f"已儲存 {qid} 的 C 作答。請執行下方 C 檢查 cell。")

@register_cell_magic
def cpp_answer(line, cell):
    qid = line.strip().upper()
    _ANSWERS["CPP"][qid] = cell
    print(f"已儲存 {qid} 的 C++ 作答。請執行下方 C++ 檢查 cell。")

def _run_check(qid, language):
    qid = qid.upper()
    language = language.upper()

    if language not in _ANSWERS:
        print("❌ language 必須是 'C' 或 'CPP'")
        return

    label = "C" if language == "C" else "C++"

    if qid not in _ANSWERS[language]:
        print(f"❌ {qid}：尚未執行 {label} 作答 cell")
        _RESULTS[language][qid] = False
        return

    source = _ANSWERS[language][qid]
    cases = _TEST_CASES[qid]
    passed = 0

    for case_number, case in enumerate(cases, start=1):
        ok_run, stdout, error = _compile_and_run(
            source,
            case["input"],
            language,
        )

        if not ok_run:
            print(f"❌ {qid}（{label}）：編譯或執行失敗")
            print(error)
            _RESULTS[language][qid] = False
            return

        actual = _normalise_output(stdout)
        expected = _normalise_output(case["expected"])

        if actual == expected:
            passed += 1
        else:
            print(f"❌ {qid}（{label}）測試 {case_number} 未通過")
            print("測試輸入：")
            print(case["input"], end="")
            print("你的輸出：")
            print(stdout if stdout else "<沒有輸出>")
            print("預期輸出：")
            print(case["expected"], end="")
            print()

    success = passed == len(cases)
    _RESULTS[language][qid] = success

    if success:
        print(f"✅ {qid}（{label}）全部通過（{passed} / {len(cases)}）")
    else:
        print(f"❌ {qid}（{label}）：通過 {passed} / {len(cases)} 個測試")

def _language_report(language):
    language = language.upper()
    label = "C" if language == "C" else "C++"
    results = _RESULTS[language]

    passed = sum(results.get(f"Q{i}", False) for i in range(1, 51))
    untouched = [f"Q{i}" for i in range(1, 51) if f"Q{i}" not in results]

    print(f"{label}：{passed} / 50 題通過")
    if untouched:
        print("尚未執行檢查：" + ", ".join(untouched))

def _final_report():
    print("=== C / C++ 總檢查 ===")
    _language_report("C")
    print()
    _language_report("CPP")

    both_passed = sum(
        _RESULTS["C"].get(f"Q{i}", False)
        and _RESULTS["CPP"].get(f"Q{i}", False)
        for i in range(1, 51)
    )
    print()
    print(f"C 與 C++ 都通過：{both_passed} / 50 題")

print("C / C++ 自動檢查工具已載入。")
print("C 使用 C11；C++ 使用 C++17。")
print("作答後不需要手動輸入測試資料。")
# Out:
# C / C++ 自動檢查工具已載入。
# C 使用 C11；C++ 使用 C++17。
# 作答後不需要手動輸入測試資料。

# %% [markdown]
# ## 作答方式提醒
#
# 每題流程：
#
# ```text
# 題目
# ↓
# C 作答 cell ─────→ C 檢查
# ↓
# C++ 作答 cell ───→ C++ 檢查
# ↓
# 同一組 3 組測試資料
# ↓
# ✅ 通過 / ❌ 顯示差異
# ```
#
# 只修改 `%%c_answer Q...` 與 `%%cpp_answer Q...` cell 裡的程式內容；不要修改檢查 cell。
#
# ### 語言差異提醒
#
# - C 輸入輸出：通常使用 `scanf()` / `printf()`
# - C++ 輸入輸出：通常使用 `cin` / `cout`
# - Q39–Q40：
#   - C 使用一般 `for` + index 逐字元走訪
#   - C++ 使用 `range-based for`

# %% [markdown]
# ---
#
# # Part A：Lesson 06 — `if` 條件判斷（Q1–Q10）

# %% [markdown]
# ## Q1. 正數旗標
#
# 讀入一個整數 x。令 result 初始為 0；若 x > 0，將 result 改成 1，最後輸出 result。
#
# **練習重點：** 基本 `if` 與條件成立時才更新變數
#
# **輸入：** 一個整數 x。
#
# **輸出：** 輸出 0 或 1。
#
# **範例輸入：**
#
# ```text
# 8
# ```
#
# **範例輸出：**
#
# ```text
# 1
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q1
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q1

# %%
# 檢查 Q1（C）：完成上方 C 程式後執行
_run_check("Q1", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q1
# #include <iostream>
# using namespace std;
#
# int main() {
#     int x;
#     int result = 0;
#
#     cin >> x;
#
#     if (x > 0) {
#         result = 1;
#     }
#
#     cout << result << endl;
#
#     return 0;
# }
# Out:
# 已儲存 Q1 的 C++ 作答。請執行下方 C++ 檢查 cell。

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q1

# %%
# 檢查 Q1（C++）：完成上方 C++ 程式後執行
_run_check("Q1", "CPP")
# Out:
# ✅ Q1（C++）全部通過（3 / 3）

# %% [markdown]
# ## Q2. 正負零分類
#
# 讀入整數 x，使用三個彼此獨立的 `if` 判斷，輸出 `POSITIVE`、`NEGATIVE` 或 `ZERO`。
#
# **練習重點：** 獨立 `if` 與互斥條件
#
# **輸入：** 一個整數 x。
#
# **輸出：** 輸出分類字串。
#
# **範例輸入：**
#
# ```text
# 17
# ```
#
# **範例輸出：**
#
# ```text
# POSITIVE
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q2
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q2

# %%
# 檢查 Q2（C）：完成上方 C 程式後執行
_run_check("Q2", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q2
# #include <iostream>
# using namespace std;
#
# int main() {
#     int x;
#
#     cin >> x;
#
#     if (x > 0) cout << "POSITIVE\n";
#     if (x < 0) cout << "NEGATIVE\n";
#     if (x == 0) cout << "ZERO\n";
#
#     return 0;
# }
# Out:
# 已儲存 Q2 的 C++ 作答。請執行下方 C++ 檢查 cell。

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q2

# %%
# 檢查 Q2（C++）：完成上方 C++ 程式後執行
_run_check("Q2", "CPP")
# Out:
# ✅ Q2（C++）全部通過（3 / 3）

# %% [markdown]
# ## Q3. 可被 2 與 3 整除的條件數
#
# 讀入整數 x。分別判斷它是否可被 2、3 整除；每成立一個條件就加 1，輸出最後計數。
#
# **練習重點：** 多個獨立 `if`、取餘數
#
# **輸入：** 一個整數 x。
#
# **輸出：** 輸出 0、1 或 2。
#
# **範例輸入：**
#
# ```text
# 12
# ```
#
# **範例輸出：**
#
# ```text
# 2
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q3
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q3

# %%
# 檢查 Q3（C）：完成上方 C 程式後執行
_run_check("Q3", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q3
# #include <iostream>
# using namespace std;
#
# int main() {
#     int x;
#     int count = 0;
#
#     cin >> x;
#
#     if (x % 2 == 0) count++;
#     if (x % 3 == 0) count++;
#
#     cout << count << endl;
#
#     return 0;
# }
# Out:
# 已儲存 Q3 的 C++ 作答。請執行下方 C++ 檢查 cell。

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q3

# %%
# 檢查 Q3（C++）：完成上方 C++ 程式後執行
_run_check("Q3", "CPP")
# Out:
# ✅ Q3（C++）全部通過（3 / 3）

# %% [markdown]
# ## Q4. 閉區間判斷
#
# 讀入整數 x，判斷 x 是否位於閉區間 [10, 20]。成立輸出 1，否則輸出 0。
#
# **練習重點：** `&&` 與範圍條件
#
# **輸入：** 一個整數 x。
#
# **輸出：** 輸出 0 或 1。
#
# **範例輸入：**
#
# ```text
# 15
# ```
#
# **範例輸出：**
#
# ```text
# 1
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q4
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q4

# %%
# 檢查 Q4（C）：完成上方 C 程式後執行
_run_check("Q4", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q4
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q4

# %%
# 檢查 Q4（C++）：完成上方 C++ 程式後執行
_run_check("Q4", "CPP")

# %% [markdown]
# ## Q5. 區間外判斷
#
# 讀入整數 x，判斷 x 是否在 [10, 20] 之外。成立輸出 1，否則輸出 0。
#
# **練習重點：** `||` 與區間外條件
#
# **輸入：** 一個整數 x。
#
# **輸出：** 輸出 0 或 1。
#
# **範例輸入：**
#
# ```text
# 7
# ```
#
# **範例輸出：**
#
# ```text
# 1
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q5
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q5

# %%
# 檢查 Q5（C）：完成上方 C 程式後執行
_run_check("Q5", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q5
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q5

# %%
# 檢查 Q5（C++）：完成上方 C++ 程式後執行
_run_check("Q5", "CPP")

# %% [markdown]
# ## Q6. 條件式折扣
#
# 讀入整數 price。若 price >= 1000，將價格打九折（`price = price * 90 / 100`）；否則保持原價。輸出最後價格。
#
# **練習重點：** 條件成立時修改既有狀態
#
# **輸入：** 一個非負整數 price。
#
# **輸出：** 輸出折扣後整數價格。
#
# **範例輸入：**
#
# ```text
# 1500
# ```
#
# **範例輸出：**
#
# ```text
# 1350
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q6
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q6

# %%
# 檢查 Q6（C）：完成上方 C 程式後執行
_run_check("Q6", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q6
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q6

# %%
# 檢查 Q6（C++）：完成上方 C++ 程式後執行
_run_check("Q6", "CPP")

# %% [markdown]
# ## Q7. 安全整除判斷
#
# 讀入整數 a、b。只有在 b != 0 且 a 可被 b 整除時輸出 1，其他情況輸出 0。條件式應避免 b 為 0 時執行 `% b`。
#
# **練習重點：** 短路求值 `&&` 與除零安全
#
# **輸入：** 兩個整數 a、b。
#
# **輸出：** 輸出 0 或 1。
#
# **範例輸入：**
#
# ```text
# 20 5
# ```
#
# **範例輸出：**
#
# ```text
# 1
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q7
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q7

# %%
# 檢查 Q7（C）：完成上方 C 程式後執行
_run_check("Q7", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q7
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q7

# %%
# 檢查 Q7（C++）：完成上方 C++ 程式後執行
_run_check("Q7", "CPP")

# %% [markdown]
# ## Q8. 兩層資格門檻
#
# 讀入 age 與 score。只有 age >= 18 時才進一步檢查 score >= 60；兩條件都成立輸出 1，否則輸出 0。
#
# **練習重點：** 巢狀 `if`
#
# **輸入：** 兩個整數 age、score。
#
# **輸出：** 輸出 0 或 1。
#
# **範例輸入：**
#
# ```text
# 20 75
# ```
#
# **範例輸出：**
#
# ```text
# 1
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q8
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q8

# %%
# 檢查 Q8（C）：完成上方 C 程式後執行
_run_check("Q8", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q8
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q8

# %%
# 檢查 Q8（C++）：完成上方 C++ 程式後執行
_run_check("Q8", "CPP")

# %% [markdown]
# ## Q9. 三角形有效性
#
# 讀入三個整數邊長 a、b、c。三邊都必須大於 0，且任兩邊和大於第三邊，才輸出 1；否則輸出 0。
#
# **練習重點：** 多條件 `&&` 與三角形不等式
#
# **輸入：** 三個整數 a、b、c。
#
# **輸出：** 輸出 0 或 1。
#
# **範例輸入：**
#
# ```text
# 3 4 5
# ```
#
# **範例輸出：**
#
# ```text
# 1
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q9
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q9

# %%
# 檢查 Q9（C）：完成上方 C 程式後執行
_run_check("Q9", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q9
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q9

# %%
# 檢查 Q9（C++）：完成上方 C++ 程式後執行
_run_check("Q9", "CPP")

# %% [markdown]
# ## Q10. 直角三角形判斷
#
# 讀入三個正整數 a、b、c，順序不固定。若三組平方關係中任一組符合畢氏定理，輸出 1，否則輸出 0。
#
# **練習重點：** `||` 組合多種可能情況
#
# **輸入：** 三個正整數 a、b、c。
#
# **輸出：** 輸出 0 或 1。
#
# **範例輸入：**
#
# ```text
# 3 4 5
# ```
#
# **範例輸出：**
#
# ```text
# 1
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q10
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q10

# %%
# 檢查 Q10（C）：完成上方 C 程式後執行
_run_check("Q10", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q10
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q10

# %%
# 檢查 Q10（C++）：完成上方 C++ 程式後執行
_run_check("Q10", "CPP")

# %% [markdown]
# ---
#
# # Part B：Lesson 07 — `if / else / switch`（Q11–Q20）

# %% [markdown]
# ## Q11. 奇偶二選一
#
# 讀入整數 x。偶數輸出 `EVEN`，否則輸出 `ODD`。
#
# **練習重點：** `if ... else` 二分支
#
# **輸入：** 一個整數 x。
#
# **輸出：** 輸出 `EVEN` 或 `ODD`。
#
# **範例輸入：**
#
# ```text
# 14
# ```
#
# **範例輸出：**
#
# ```text
# EVEN
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q11
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q11

# %%
# 檢查 Q11（C）：完成上方 C 程式後執行
_run_check("Q11", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q11
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q11

# %%
# 檢查 Q11（C++）：完成上方 C++ 程式後執行
_run_check("Q11", "CPP")

# %% [markdown]
# ## Q12. 兩數較大值
#
# 讀入 a、b，使用 `if ... else` 輸出較大的數；若相等，輸出該數。
#
# **練習重點：** 二分支選擇
#
# **輸入：** 兩個整數 a、b。
#
# **輸出：** 輸出較大值。
#
# **範例輸入：**
#
# ```text
# 8 3
# ```
#
# **範例輸出：**
#
# ```text
# 8
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q12
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q12

# %%
# 檢查 Q12（C）：完成上方 C 程式後執行
_run_check("Q12", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q12
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q12

# %%
# 檢查 Q12（C++）：完成上方 C++ 程式後執行
_run_check("Q12", "CPP")

# %% [markdown]
# ## Q13. 三種比較結果
#
# 讀入 a、b。若 a>b 輸出 `GREATER`；a<b 輸出 `LESS`；相等輸出 `EQUAL`。
#
# **練習重點：** `else if` 三分支
#
# **輸入：** 兩個整數 a、b。
#
# **輸出：** 輸出三種字串之一。
#
# **範例輸入：**
#
# ```text
# 9 2
# ```
#
# **範例輸出：**
#
# ```text
# GREATER
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q13
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q13

# %%
# 檢查 Q13（C）：完成上方 C 程式後執行
_run_check("Q13", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q13
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q13

# %%
# 檢查 Q13（C++）：完成上方 C++ 程式後執行
_run_check("Q13", "CPP")

# %% [markdown]
# ## Q14. 成績等第
#
# 讀入 0~100 的整數 score：90 以上 A、80~89 B、70~79 C、60~69 D、其餘 F。
#
# **練習重點：** 門檻由高到低的 `else if`
#
# **輸入：** 一個整數 score。
#
# **輸出：** 輸出 `A/B/C/D/F`。
#
# **範例輸入：**
#
# ```text
# 95
# ```
#
# **範例輸出：**
#
# ```text
# A
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q14
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q14

# %%
# 檢查 Q14（C）：完成上方 C 程式後執行
_run_check("Q14", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q14
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q14

# %%
# 檢查 Q14（C++）：完成上方 C++ 程式後執行
_run_check("Q14", "CPP")

# %% [markdown]
# ## Q15. 三數最大值
#
# 讀入三個整數 a、b、c。先令最大值為 a，再依序比較 b、c，輸出最大值。
#
# **練習重點：** running maximum
#
# **輸入：** 三個整數 a、b、c。
#
# **輸出：** 輸出最大值。
#
# **範例輸入：**
#
# ```text
# 3 9 5
# ```
#
# **範例輸出：**
#
# ```text
# 9
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q15
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q15

# %%
# 檢查 Q15（C）：完成上方 C 程式後執行
_run_check("Q15", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q15
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q15

# %%
# 檢查 Q15（C++）：完成上方 C++ 程式後執行
_run_check("Q15", "CPP")

# %% [markdown]
# ## Q16. 簡易整數計算機
#
# 讀入 `a op b`。op 為 `+ - * /`。除法使用整數除法；若除數為 0 或運算子不合法，輸出 `INVALID`。
#
# **練習重點：** `else if` 計算機與除零檢查
#
# **輸入：** 整數 a、字元 op、整數 b。
#
# **輸出：** 輸出整數結果或 `INVALID`。
#
# **範例輸入：**
#
# ```text
# 12 + 5
# ```
#
# **範例輸出：**
#
# ```text
# 17
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q16
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q16

# %%
# 檢查 Q16（C）：完成上方 C 程式後執行
_run_check("Q16", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q16
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q16

# %%
# 檢查 Q16（C++）：完成上方 C++ 程式後執行
_run_check("Q16", "CPP")

# %% [markdown]
# ## Q17. 星期選擇器
#
# 讀入 1~7，以 `switch` 對應 `MON` 到 `SUN`；其他值輸出 `INVALID`。
#
# **練習重點：** `switch` 基本 case matching
#
# **輸入：** 一個整數 day。
#
# **輸出：** 輸出星期縮寫或 `INVALID`。
#
# **範例輸入：**
#
# ```text
# 1
# ```
#
# **範例輸出：**
#
# ```text
# MON
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q17
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q17

# %%
# 檢查 Q17（C）：完成上方 C 程式後執行
_run_check("Q17", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q17
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q17

# %%
# 檢查 Q17（C++）：完成上方 C++ 程式後執行
_run_check("Q17", "CPP")

# %% [markdown]
# ## Q18. 月份天數
#
# 讀入月份 1~12，不考慮閏年。用 `switch` 與共享 cases 輸出該月天數；非法月份輸出 `INVALID`。
#
# **練習重點：** 共享 `case` 與 `break`
#
# **輸入：** 一個整數 month。
#
# **輸出：** 輸出 28、30、31 或 `INVALID`。
#
# **範例輸入：**
#
# ```text
# 2
# ```
#
# **範例輸出：**
#
# ```text
# 28
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q18
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q18

# %%
# 檢查 Q18（C）：完成上方 C 程式後執行
_run_check("Q18", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q18
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q18

# %%
# 檢查 Q18（C++）：完成上方 C++ 程式後執行
_run_check("Q18", "CPP")

# %% [markdown]
# ## Q19. 母音共享 cases
#
# 讀入一個大寫英文字母。若為 A/E/I/O/U，輸出 `VOWEL`，否則輸出 `OTHER`。請用 `switch` 的多個共享 cases。
#
# **練習重點：** switch fallthrough/shared cases
#
# **輸入：** 一個大寫字母。
#
# **輸出：** 輸出 `VOWEL` 或 `OTHER`。
#
# **範例輸入：**
#
# ```text
# A
# ```
#
# **範例輸出：**
#
# ```text
# VOWEL
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q19
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q19

# %%
# 檢查 Q19（C）：完成上方 C 程式後執行
_run_check("Q19", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q19
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q19

# %%
# 檢查 Q19（C++）：完成上方 C++ 程式後執行
_run_check("Q19", "CPP")

# %% [markdown]
# ## Q20. 產品代號對應
#
# 讀入字元代號：A→100、B→200、C→300；其他輸出 -1。請使用 `switch`。
#
# **練習重點：** `switch` + `default`
#
# **輸入：** 一個字元。
#
# **輸出：** 輸出對應整數。
#
# **範例輸入：**
#
# ```text
# A
# ```
#
# **範例輸出：**
#
# ```text
# 100
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q20
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q20

# %%
# 檢查 Q20（C）：完成上方 C 程式後執行
_run_check("Q20", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q20
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q20

# %%
# 檢查 Q20（C++）：完成上方 C++ 程式後執行
_run_check("Q20", "CPP")

# %% [markdown]
# ---
#
# # Part C：Lesson 08 — `while / do...while`（Q21–Q30）

# %% [markdown]
# ## Q21. while 累加 1 到 n
#
# 讀入正整數 n，使用 `while` 計算 1+2+...+n。
#
# **練習重點：** while 的初始化、條件、更新與 accumulator
#
# **輸入：** 一個正整數 n。
#
# **輸出：** 輸出總和。
#
# **範例輸入：**
#
# ```text
# 5
# ```
#
# **範例輸出：**
#
# ```text
# 15
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q21
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q21

# %%
# 檢查 Q21（C）：完成上方 C 程式後執行
_run_check("Q21", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q21
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q21

# %%
# 檢查 Q21（C++）：完成上方 C++ 程式後執行
_run_check("Q21", "CPP")

# %% [markdown]
# ## Q22. while 倒數
#
# 讀入正整數 n，使用 `while` 從 n 倒數到 1，每個數各輸出一行。
#
# **練習重點：** 遞減 while 與終止條件
#
# **輸入：** 一個正整數 n。
#
# **輸出：** 每行輸出一個整數。
#
# **範例輸入：**
#
# ```text
# 4
# ```
#
# **範例輸出：**
#
# ```text
# 4
# 3
# 2
# 1
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q22
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q22

# %%
# 檢查 Q22（C）：完成上方 C 程式後執行
_run_check("Q22", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q22
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q22

# %%
# 檢查 Q22（C++）：完成上方 C++ 程式後執行
_run_check("Q22", "CPP")

# %% [markdown]
# ## Q23. 整數位數
#
# 讀入非負整數 n，使用 `while` 計算十進位位數。特別規定 0 有 1 位。
#
# **練習重點：** while 與零的邊界情況
#
# **輸入：** 一個非負整數 n。
#
# **輸出：** 輸出位數。
#
# **範例輸入：**
#
# ```text
# 5831
# ```
#
# **範例輸出：**
#
# ```text
# 4
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q23
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q23

# %%
# 檢查 Q23（C）：完成上方 C 程式後執行
_run_check("Q23", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q23
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q23

# %%
# 檢查 Q23（C++）：完成上方 C++ 程式後執行
_run_check("Q23", "CPP")

# %% [markdown]
# ## Q24. 各位數總和
#
# 讀入非負整數 n，重複取 `n % 10` 並令 `n /= 10`，計算各位數總和。
#
# **練習重點：** while、取餘數與逐位處理
#
# **輸入：** 一個非負整數 n。
#
# **輸出：** 輸出位數總和。
#
# **範例輸入：**
#
# ```text
# 5831
# ```
#
# **範例輸出：**
#
# ```text
# 17
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q24
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q24

# %%
# 檢查 Q24（C）：完成上方 C 程式後執行
_run_check("Q24", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q24
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q24

# %%
# 檢查 Q24（C++）：完成上方 C++ 程式後執行
_run_check("Q24", "CPP")

# %% [markdown]
# ## Q25. 反轉整數
#
# 讀入非負整數 n，使用 `while` 反轉十進位數字；前導零自然消失。
#
# **練習重點：** while 與逐位建構答案
#
# **輸入：** 一個非負整數 n。
#
# **輸出：** 輸出反轉後整數。
#
# **範例輸入：**
#
# ```text
# 5831
# ```
#
# **範例輸出：**
#
# ```text
# 1385
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q25
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q25

# %%
# 檢查 Q25（C）：完成上方 C 程式後執行
_run_check("Q25", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q25
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q25

# %%
# 檢查 Q25（C++）：完成上方 C++ 程式後執行
_run_check("Q25", "CPP")

# %% [markdown]
# ## Q26. 哨兵值總和
#
# 持續讀入整數，遇到 -1 結束；-1 不算資料。輸出之前所有數字的總和。
#
# **練習重點：** sentinel value / priming read
#
# **輸入：** 一串整數，最後一定有 -1。
#
# **輸出：** 輸出總和。
#
# **範例輸入：**
#
# ```text
# 5 8 2 -1
# ```
#
# **範例輸出：**
#
# ```text
# 15
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q26
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q26

# %%
# 檢查 Q26（C）：完成上方 C 程式後執行
_run_check("Q26", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q26
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q26

# %%
# 檢查 Q26（C++）：完成上方 C++ 程式後執行
_run_check("Q26", "CPP")

# %% [markdown]
# ## Q27. 哨兵值平均
#
# 持續讀入整數直到 -1。輸出資料平均值到小數點後 2 位；若第一個數就是 -1，輸出 `0.00`。
#
# **練習重點：** sum + count 與 zero-data guard
#
# **輸入：** 一串整數，最後一定有 -1。
#
# **輸出：** 輸出平均值到小數點後 2 位。
#
# **範例輸入：**
#
# ```text
# 10 20 30 -1
# ```
#
# **範例輸出：**
#
# ```text
# 20.00
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q27
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q27

# %%
# 檢查 Q27（C）：完成上方 C 程式後執行
_run_check("Q27", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q27
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q27

# %%
# 檢查 Q27（C++）：完成上方 C++ 程式後執行
_run_check("Q27", "CPP")

# %% [markdown]
# ## Q28. do-while 輸入驗證
#
# 輸入一串整數。使用 `do...while` 反覆讀取，直到讀到 1~10 之間的值。輸出第一個合法值與總嘗試次數。
#
# **練習重點：** do-while 至少執行一次與 input validation
#
# **輸入：** 至少包含一個 1~10 的整數。
#
# **輸出：** 輸出 `合法值 嘗試次數`。
#
# **範例輸入：**
#
# ```text
# -3 15 7
# ```
#
# **範例輸出：**
#
# ```text
# 7 3
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q28
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q28

# %%
# 檢查 Q28（C）：完成上方 C 程式後執行
_run_check("Q28", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q28
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q28

# %%
# 檢查 Q28（C++）：完成上方 C++ 程式後執行
_run_check("Q28", "CPP")

# %% [markdown]
# ## Q29. do-while 由 1 印到 n
#
# 讀入正整數 n，使用 `do...while` 依序輸出 1 到 n，每個數各一行。
#
# **練習重點：** do-while 基本循環
#
# **輸入：** 一個正整數 n。
#
# **輸出：** 每行輸出一個整數。
#
# **範例輸入：**
#
# ```text
# 4
# ```
#
# **範例輸出：**
#
# ```text
# 1
# 2
# 3
# 4
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q29
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q29

# %%
# 檢查 Q29（C）：完成上方 C 程式後執行
_run_check("Q29", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q29
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q29

# %%
# 檢查 Q29（C++）：完成上方 C++ 程式後執行
_run_check("Q29", "CPP")

# %% [markdown]
# ## Q30. 猜數字嘗試次數
#
# 第一個整數為 target，後面是一連串猜測值，且最後一定會猜中。使用 `do...while` 讀取猜測，輸出猜中的嘗試次數。
#
# **練習重點：** do-while 與終止條件
#
# **輸入：** target 後接至少一個 guess。
#
# **輸出：** 輸出嘗試次數。
#
# **範例輸入：**
#
# ```text
# 7 3 5 7
# ```
#
# **範例輸出：**
#
# ```text
# 3
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q30
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q30

# %%
# 檢查 Q30（C）：完成上方 C 程式後執行
_run_check("Q30", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q30
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q30

# %%
# 檢查 Q30（C++）：完成上方 C++ 程式後執行
_run_check("Q30", "CPP")

# %% [markdown]
# ---
#
# # Part D：Lesson 09 — `for / break / continue`，C++ `range-based for`（Q31–Q40）

# %% [markdown]
# ## Q31. for 累加 1 到 n
#
# 讀入正整數 n，使用傳統 `for` 計算 1 到 n 的總和。
#
# **練習重點：** traditional for + accumulator
#
# **輸入：** 一個正整數 n。
#
# **輸出：** 輸出總和。
#
# **範例輸入：**
#
# ```text
# 10
# ```
#
# **範例輸出：**
#
# ```text
# 55
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q31
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q31

# %%
# 檢查 Q31（C）：完成上方 C 程式後執行
_run_check("Q31", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q31
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q31

# %%
# 檢查 Q31（C++）：完成上方 C++ 程式後執行
_run_check("Q31", "CPP")

# %% [markdown]
# ## Q32. 階乘
#
# 讀入 0~12 的整數 n，使用 `for` 計算 n!；規定 0! = 1。
#
# **練習重點：** for 乘法 accumulator
#
# **輸入：** 一個整數 n。
#
# **輸出：** 輸出 n!。
#
# **範例輸入：**
#
# ```text
# 5
# ```
#
# **範例輸出：**
#
# ```text
# 120
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q32
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q32

# %%
# 檢查 Q32（C）：完成上方 C 程式後執行
_run_check("Q32", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q32
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q32

# %%
# 檢查 Q32（C++）：完成上方 C++ 程式後執行
_run_check("Q32", "CPP")

# %% [markdown]
# ## Q33. 固定步長倍數
#
# 讀入 n、k（1<=k<=n），使用 `for` 輸出 k、2k、3k... 中不超過 n 的數，每個各一行。
#
# **練習重點：** for 的非 1 步長
#
# **輸入：** 兩個正整數 n、k。
#
# **輸出：** 每行輸出一個倍數。
#
# **範例輸入：**
#
# ```text
# 20 4
# ```
#
# **範例輸出：**
#
# ```text
# 4
# 8
# 12
# 16
# 20
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q33
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q33

# %%
# 檢查 Q33（C）：完成上方 C 程式後執行
_run_check("Q33", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q33
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q33

# %%
# 檢查 Q33（C++）：完成上方 C++ 程式後執行
_run_check("Q33", "CPP")

# %% [markdown]
# ## Q34. for 反向迴圈
#
# 讀入正整數 n，使用 `for` 從 n 倒數到 1，每個數各一行。
#
# **練習重點：** 反向 for 與更新方向
#
# **輸入：** 一個正整數 n。
#
# **輸出：** 每行輸出一個整數。
#
# **範例輸入：**
#
# ```text
# 5
# ```
#
# **範例輸出：**
#
# ```text
# 5
# 4
# 3
# 2
# 1
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q34
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q34

# %%
# 檢查 Q34（C）：完成上方 C 程式後執行
_run_check("Q34", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q34
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q34

# %%
# 檢查 Q34（C++）：完成上方 C++ 程式後執行
_run_check("Q34", "CPP")

# %% [markdown]
# ## Q35. 直接產生奇數
#
# 讀入正整數 n，使用步長 2 的 `for` 輸出 1 到 n 的所有奇數，每個各一行。
#
# **練習重點：** generation vs filtering
#
# **輸入：** 一個正整數 n。
#
# **輸出：** 每行輸出一個奇數。
#
# **範例輸入：**
#
# ```text
# 9
# ```
#
# **範例輸出：**
#
# ```text
# 1
# 3
# 5
# 7
# 9
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q35
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q35

# %%
# 檢查 Q35（C）：完成上方 C 程式後執行
_run_check("Q35", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q35
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q35

# %%
# 檢查 Q35（C++）：完成上方 C++ 程式後執行
_run_check("Q35", "CPP")

# %% [markdown]
# ## Q36. 因數個數
#
# 讀入正整數 n，用 `for` 檢查 1~n，計算 n 的正因數個數。
#
# **練習重點：** for + divisibility
#
# **輸入：** 一個正整數 n。
#
# **輸出：** 輸出因數個數。
#
# **範例輸入：**
#
# ```text
# 12
# ```
#
# **範例輸出：**
#
# ```text
# 6
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q36
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q36

# %%
# 檢查 Q36（C）：完成上方 C 程式後執行
_run_check("Q36", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q36
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q36

# %%
# 檢查 Q36（C++）：完成上方 C++ 程式後執行
_run_check("Q36", "CPP")

# %% [markdown]
# ## Q37. 質數判斷與 break
#
# 讀入正整數 n。若 n 是質數輸出 `PRIME`，否則輸出 `NOT PRIME`。找到因數後可立即 `break`。
#
# **練習重點：** for + break / early exit
#
# **輸入：** 一個正整數 n。
#
# **輸出：** 輸出 `PRIME` 或 `NOT PRIME`。
#
# **範例輸入：**
#
# ```text
# 29
# ```
#
# **範例輸出：**
#
# ```text
# PRIME
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q37
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q37

# %%
# 檢查 Q37（C）：完成上方 C 程式後執行
_run_check("Q37", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q37
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q37

# %%
# 檢查 Q37（C++）：完成上方 C++ 程式後執行
_run_check("Q37", "CPP")

# %% [markdown]
# ## Q38. continue 過濾 3 的倍數
#
# 讀入正整數 n。計算 1~n 中所有「不是 3 的倍數」的整數總和；遇到 3 的倍數時使用 `continue` 跳過。
#
# **練習重點：** for + continue
#
# **輸入：** 一個正整數 n。
#
# **輸出：** 輸出總和。
#
# **範例輸入：**
#
# ```text
# 10
# ```
#
# **範例輸出：**
#
# ```text
# 37
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q38
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q38

# %%
# 檢查 Q38（C）：完成上方 C 程式後執行
_run_check("Q38", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q38
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q38

# %%
# 檢查 Q38（C++）：完成上方 C++ 程式後執行
_run_check("Q38", "CPP")

# %% [markdown]
# ## Q39. 字串逐字元走訪：大寫字母數
#
# 讀入一個不含空白的字串 `word`，逐字元走訪，計算其中 `A`~`Z` 的字元數。
#
# - **C：** 使用一般 `for` + index
# - **C++：** 使用 `range-based for`
#
# **練習重點：** C 的 index 走訪；C++ 的 `range-based for`
#
# **輸入：** 一個不含空白的字串。
#
# **輸出：** 輸出大寫字母數。
#
# **範例輸入：**
#
# ```text
# AbCdeF
# ```
#
# **範例輸出：**
#
# ```text
# 3
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q39
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q39

# %%
# 檢查 Q39（C）：完成上方 C 程式後執行
_run_check("Q39", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q39
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q39

# %%
# 檢查 Q39（C++）：完成上方 C++ 程式後執行
_run_check("Q39", "CPP")

# %% [markdown]
# ## Q40. 字串逐字元走訪：數字字元總和
#
# 讀入一個不含空白的字串，逐字元走訪。若字元介於 `'0'` 到 `'9'`，就把其數值加入總和。
#
# - **C：** 使用一般 `for` + index
# - **C++：** 使用 `range-based for`
#
# **練習重點：** 字串逐字元走訪 + 字元條件；C++ 練習 `range-based for`
#
# **輸入：** 一個不含空白的字串。
#
# **輸出：** 輸出所有數字字元的數值總和。
#
# **範例輸入：**
#
# ```text
# A1B2C3
# ```
#
# **範例輸出：**
#
# ```text
# 6
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q40
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q40

# %%
# 檢查 Q40（C）：完成上方 C 程式後執行
_run_check("Q40", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q40
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q40

# %%
# 檢查 Q40（C++）：完成上方 C++ 程式後執行
_run_check("Q40", "CPP")

# %% [markdown]
# ---
#
# # Part E：Lesson 10 — 巢狀迴圈（Q41–Q50）

# %% [markdown]
# ## Q41. 實心長方形
#
# 讀入 rows、cols，使用兩層迴圈輸出 rows×cols 的 `#` 長方形。
#
# **練習重點：** 外層列、內層欄
#
# **輸入：** 兩個正整數 rows、cols。
#
# **輸出：** 輸出指定大小的圖形。
#
# **範例輸入：**
#
# ```text
# 3 5
# ```
#
# **範例輸出：**
#
# ```text
# #####
# #####
# #####
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q41
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q41

# %%
# 檢查 Q41（C）：完成上方 C 程式後執行
_run_check("Q41", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q41
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q41

# %%
# 檢查 Q41（C++）：完成上方 C++ 程式後執行
_run_check("Q41", "CPP")

# %% [markdown]
# ## Q42. 左下直角三角形
#
# 讀入 n，第 i 列輸出 i 個 `#`，共 n 列。
#
# **練習重點：** 內層範圍由外層變數控制
#
# **輸入：** 一個正整數 n。
#
# **輸出：** 輸出 n 列三角形。
#
# **範例輸入：**
#
# ```text
# 4
# ```
#
# **範例輸出：**
#
# ```text
# #
# ##
# ###
# ####
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q42
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q42

# %%
# 檢查 Q42（C）：完成上方 C 程式後執行
_run_check("Q42", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q42
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q42

# %%
# 檢查 Q42（C++）：完成上方 C++ 程式後執行
_run_check("Q42", "CPP")

# %% [markdown]
# ## Q43. 倒三角形
#
# 讀入 n，依序輸出 n、n-1、...、1 個 `#`。
#
# **練習重點：** 巢狀迴圈與遞減列長
#
# **輸入：** 一個正整數 n。
#
# **輸出：** 輸出倒三角形。
#
# **範例輸入：**
#
# ```text
# 4
# ```
#
# **範例輸出：**
#
# ```text
# ####
# ###
# ##
# #
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q43
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q43

# %%
# 檢查 Q43（C）：完成上方 C 程式後執行
_run_check("Q43", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q43
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q43

# %%
# 檢查 Q43（C++）：完成上方 C++ 程式後執行
_run_check("Q43", "CPP")

# %% [markdown]
# ## Q44. n×n 乘法表
#
# 讀入 n。輸出 n×n 乘法表，第 i 列為 `i*1` 到 `i*n`，同列數字以單一空格分隔。
#
# **練習重點：** 巢狀迴圈的 row/column roles
#
# **輸入：** 一個正整數 n。
#
# **輸出：** 輸出 n 列乘法表。
#
# **範例輸入：**
#
# ```text
# 3
# ```
#
# **範例輸出：**
#
# ```text
# 1 2 3
# 2 4 6
# 3 6 9
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q44
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q44

# %%
# 檢查 Q44（C）：完成上方 C 程式後執行
_run_check("Q44", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q44
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q44

# %%
# 檢查 Q44（C++）：完成上方 C++ 程式後執行
_run_check("Q44", "CPP")

# %% [markdown]
# ## Q45. 座標列舉
#
# 讀入 rows、cols。依 row-major 順序輸出所有 `(i,j)`，i 從 1..rows、j 從 1..cols，每個座標一行。
#
# **練習重點：** 巢狀執行順序與 Cartesian product
#
# **輸入：** 兩個正整數 rows、cols。
#
# **輸出：** 每行輸出一個 `(i,j)`。
#
# **範例輸入：**
#
# ```text
# 2 3
# ```
#
# **範例輸出：**
#
# ```text
# (1,1)
# (1,2)
# (1,3)
# (2,1)
# (2,2)
# (2,3)
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q45
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q45

# %%
# 檢查 Q45（C）：完成上方 C 程式後執行
_run_check("Q45", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q45
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q45

# %%
# 檢查 Q45（C++）：完成上方 C++ 程式後執行
_run_check("Q45", "CPP")

# %% [markdown]
# ## Q46. 空心長方形
#
# 讀入 rows、cols（皆 >=2）。邊界位置輸出 `#`，內部位置輸出 `.`。
#
# **練習重點：** 座標條件與四邊界
#
# **輸入：** 兩個整數 rows、cols。
#
# **輸出：** 輸出空心長方形。
#
# **範例輸入：**
#
# ```text
# 4 6
# ```
#
# **範例輸出：**
#
# ```text
# ######
# #....#
# #....#
# ######
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q46
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q46

# %%
# 檢查 Q46（C）：完成上方 C 程式後執行
_run_check("Q46", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q46
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q46

# %%
# 檢查 Q46（C++）：完成上方 C++ 程式後執行
_run_check("Q46", "CPP")

# %% [markdown]
# ## Q47. X 圖形
#
# 讀入 n。輸出 n×n 網格；主對角線或副對角線位置輸出 `#`，其他輸出 `.`。
#
# **練習重點：** `i==j` 與 `i+j==n+1`
#
# **輸入：** 一個正整數 n。
#
# **輸出：** 輸出 X 圖形。
#
# **範例輸入：**
#
# ```text
# 5
# ```
#
# **範例輸出：**
#
# ```text
# #...#
# .#.#.
# ..#..
# .#.#.
# #...#
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q47
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q47

# %%
# 檢查 Q47（C）：完成上方 C 程式後執行
_run_check("Q47", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q47
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q47

# %%
# 檢查 Q47（C++）：完成上方 C++ 程式後執行
_run_check("Q47", "CPP")

# %% [markdown]
# ## Q48. 兩數和的配對數
#
# 讀入 n、target。在 1<=i<j<=n 的所有配對中，計算 i+j==target 的配對數。
#
# **練習重點：** 雙層搜尋與避免對稱重複
#
# **輸入：** 兩個正整數 n、target。
#
# **輸出：** 輸出符合條件的配對數。
#
# **範例輸入：**
#
# ```text
# 6 7
# ```
#
# **範例輸出：**
#
# ```text
# 3
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q48
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q48

# %%
# 檢查 Q48（C）：完成上方 C 程式後執行
_run_check("Q48", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q48
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q48

# %%
# 檢查 Q48（C++）：完成上方 C++ 程式後執行
_run_check("Q48", "CPP")

# %% [markdown]
# ## Q49. 乘積解的數量
#
# 讀入 n、target。枚舉 1<=x<=n、1<=y<=n 的所有有序配對，計算 x*y==target 的解數。
#
# **練習重點：** double-loop search space
#
# **輸入：** 兩個正整數 n、target。
#
# **輸出：** 輸出有序解數量。
#
# **範例輸入：**
#
# ```text
# 6 6
# ```
#
# **範例輸出：**
#
# ```text
# 4
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q49
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q49

# %%
# 檢查 Q49（C）：完成上方 C 程式後執行
_run_check("Q49", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q49
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q49

# %%
# 檢查 Q49（C++）：完成上方 C++ 程式後執行
_run_check("Q49", "CPP")

# %% [markdown]
# ## Q50. 右對齊空心三角形
#
# 讀入 n（n>=2），輸出 n×n 網格。三角形區域右對齊；只在斜邊、最右邊與最後一列輸出 `#`，其餘位置輸出 `.`。
#
# **練習重點：** 座標法、右對齊與空心邊界
#
# **輸入：** 一個整數 n>=2。
#
# **輸出：** 輸出 n 列、每列 n 個字元。
#
# **範例輸入：**
#
# ```text
# 5
# ```
#
# **範例輸出：**
#
# ```text
# ....#
# ...##
# ..#.#
# .#..#
# #####
# ```

# %% [markdown]
# ### C 作答

# %%
# %%c_answer Q50
# #include <stdio.h>
# #include <string.h>
# #include <ctype.h>
#
# int main(void) {
#     // TODO: 請在這裡完成 C 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C 檢查：Q50

# %%
# 檢查 Q50（C）：完成上方 C 程式後執行
_run_check("Q50", "C")

# %% [markdown]
# ### C++ 作答

# %%
# %%cpp_answer Q50
# #include <iostream>
# #include <string>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     // TODO: 請在這裡完成 C++ 程式
#
#     return 0;
# }

# %% [markdown]
# ### ▶ 執行 C++ 檢查：Q50

# %%
# 檢查 Q50（C++）：完成上方 C++ 程式後執行
_run_check("Q50", "CPP")

# %% [markdown]
# ---
#
# # 總檢查

# %%
_final_report()
